# %% [markdown]
# # Trading Strategy Testing Framework
#
# A plug-and-play framework for testing trading strategies with standardized, comparable results.
#
# | Step | What it does | Time |
# |------|-------------|------|
# | **Setup** | Connect to data providers | Once |
# | **Fetch** | Get validated OHLCV data | 1 line |
# | **Backtest** | Run strategy, get metrics | 1 line |
# | **Optimize** | Find best parameters | 1 line |
# | **Scorecard** | 4-page presentation-ready report | 1 line |

# %% [markdown]
# ---
# ## Setup

# %%
import sys, os
sys.path.insert(0, os.path.abspath('.'))

from datetime import date
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8-darkgrid')
plt.rcParams['figure.figsize'] = (14, 5)

# %% [markdown]
# ---
# ## 1. Data Layer
#
# 10 providers available. **Yahoo Finance is the best default** — unlimited history, no key.
#
# | Provider | Key? | History | Limits | Best for |
# |----------|------|---------|--------|----------|
# | **Yahoo Finance** | No | Unlimited | None | Default — use this |
# | **Alpaca** | Free acct | 5-6 years | 200/min | Best backup, reliable API |
# | **Twelve Data** | Free | Full | 800/day | Good all-rounder |
# | **Finnhub** | Free | ~1 year | 60/min | Recent data, clean API |
# | **Polygon.io** | Free | 2 years | 5/min | Delayed but solid |
# | **Tiingo** | Free | 20+ years | 1000/day | Deep history |
# | **FMP** | Free | Full | 250/day | Decent free tier |
# | **Alpha Vantage** | Free | ~100 days | 25/day | Very limited free tier |
# | **MarketStack** | Free | Full | 100/month | Testing only |
# | **CSV File** | No | Any | None | Your own data |

# %%
from data_layer import (
    DataLayer, YahooFinanceProvider,
    # Uncomment + add keys to enable more providers:
    # AlpacaProvider,       # alpaca.markets (free paper account)
    # TwelveDataProvider,   # twelvedata.com
    # FinnhubProvider,      # finnhub.io
    # PolygonProvider,      # polygon.io
    # TiingoProvider,       # tiingo.com
    # FMPProvider,          # financialmodelingprep.com
    # AlphaVantageProvider, # alphavantage.co
    # MarketStackProvider,  # marketstack.com
    # CsvFileProvider,      # local CSV files
)

dl = DataLayer()
dl.add_provider(YahooFinanceProvider())
# dl.add_provider(AlpacaProvider(api_key='...', secret_key='...'))
# dl.add_provider(TwelveDataProvider(api_key='...'))

print(f'Providers: {dl.provider_names}')
# Out:
# Providers: ['Yahoo Finance']
# /Users/rwalm/Documents/VS Code/Testing Framework/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Fetch validated data — one line
symbol = 'SPY'
df = dl.fetch(symbol, date(2022, 1, 1), date(2025, 12, 31))
print(f'{len(df)} bars, {df.index[0].date()} to {df.index[-1].date()}')
df.head()
# Out:
# [PASS] Yahoo Finance — SPY
# 1003 bars, 2022-01-03 to 2025-12-31
#                   Open        High         Low       Close     Volume
# Date
# 2022-01-03  449.314262  450.776461  447.003088  450.644379   72668200
# 2022-01-04  452.068895  452.785845  448.635113  450.493500   71178700
# 2022-01-05  450.125568  450.899117  441.748678  441.843018  104538900
# 2022-01-06  441.380823  444.144811  439.060178  441.427979   86858900
# 2022-01-07  441.437434  442.616612  438.324384  439.682800   85111600

# %% [markdown]
# ---
# ## 2. Strategies
#
# Import everything, see what's available.

# %%
from strategy import *
from backtester import *

list_strategies()
# Out:
# Available strategies:
#   - SMACrossover: Classic SMA crossover: go long when the fast SMA crosses above
#   - MeanReversion: Z-score mean reversion: long when price dips below the mean,

# %% [markdown]
# ---
# ## 3. Backtest

# %%
config = BacktestConfig(
    initial_capital=100_000,
    commission_per_order=1.00,   # $1 per trade
    slippage_bps=2.0,            # 2 basis points slippage
)

strat = SMACrossover(fast_period=10, slow_period=30)
result = Backtester(config).run(strat, df)

print(result.summary())
# Out:
# Strategy:           SMA Crossover (10/30)
# Period:             4.0 years
#
# --- Performance ---
# Total return:       +46.43%
# Annual return:      +10.03%
# CAGR:               +10.03%
# Benchmark (B&H):    +50.91%
#
# --- Risk-Adjusted ---
# Sharpe ratio:       0.91
# Sortino ratio:      1.05
# Calmar ratio:       0.61
# SQN:                1.47
# Kelly criterion:    0.4572
# Alpha (Jensen):     +26.95%
# Beta:               0.383
#
# --- Risk ---
# Max drawdown:       -16.40%
# Avg drawdown:       -1.60%
# Max DD duration:    456 bars
# Avg DD duration:    18.9 bars
# Annual volatility:  11.18%
#
# --- Trades ---
# Total trades:       13
# Win rate:           61.5%
# Profit factor:      3.89
# Expectancy:         $3,577.04
# Avg win:            +7.42%
# Avg loss:           -3.28%
# Avg trade return:   +3.31%
# Best trade:         +20.25%
# Worst trade:        -8.87%
# Median trade P&L:   $181.20
# Max consec. losses: 2
# Avg holding bars:   48.9
# Max trade duration: 139 bars
# Avg trade duration: 48.9 bars
#
# --- Exposure & Costs ---
# Days in market:     65.1%
# Turnover:           25.65x
# Total commissions:  $27.00
# Total slippage:     $557.33

# %%
# Equity curve
fig, ax = plt.subplots(figsize=(14, 6))
ax.plot(result.equity_curve.index, result.equity_curve, label='Strategy', linewidth=1.5)
ax.plot(result.benchmark_curve.index, result.benchmark_curve, label='Buy & Hold', linewidth=1.2, alpha=0.7, linestyle='--')
ax.set_title(f'{symbol} — {strat.name}', fontsize=14)
ax.set_ylabel('Portfolio Value ($)')
ax.legend()
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/ng/sj8f6d211bxfr75zt7rh669r0000gn/T/ipykernel_3394/2509794492.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ---
# ## 4. Optimize Parameters

# %%
# Grid search (try every combo)
best, params, results = optimize(
    SMACrossover, df, config,
    maximize='sharpe_ratio',
    method='grid',
    constraint=lambda p: p['fast_period'] < p['slow_period'],
    fast_period=[5, 10, 15, 20],
    slow_period=[30, 40, 50, 60],
)
print(f'Best: {params} -> Sharpe {best.sharpe_ratio:.2f}')
# Out:
#   Constraint filtered: 16 -> 16 combos
# Optimizing SMACrossover [grid] over 16 combinations
#   Maximizing: sharpe_ratio
#   Workers: 15
#   Progress: 1/16 (6%) | Elapsed: 1s | ETA: 8s
#   Progress: 2/16 (12%) | Elapsed: 1s | ETA: 4s
#   Progress: 3/16 (19%) | Elapsed: 1s | ETA: 2s
#   Progress: 4/16 (25%) | Elapsed: 1s | ETA: 2s
#   Progress: 5/16 (31%) | Elapsed: 1s | ETA: 1s
#   Progress: 6/16 (38%) | Elapsed: 1s | ETA: 1s
#   Progress: 7/16 (44%) | Elapsed: 1s | ETA: 1s
#   Progress: 8/16 (50%) | Elapsed: 1s | ETA: 1s
#   Progress: 9/16 (56%) | Elapsed: 1s | ETA: 0s
#   Progress: 10/16 (62%) | Elapsed: 1s | ETA: 0s
#   Progress: 11/16 (69%) | Elapsed: 1s | ETA: 0s
#   Progress: 12/16 (75%) | Elapsed: 1s | ETA: 0s
#   Progress: 13/16 (81%) | Elapsed: 1s | ETA: 0s
#   Progress: 14/16 (88%) | Elapsed: 1s | ETA: 0s
#   Progress: 15/16 (94%) | Elapsed: 1s | ETA: 0s
#   Progress: 16/16 (100%) | Elapsed: 1s | ETA: 0s
# Optimization complete in 0.6s
#   Best sharpe_ratio: 1.0381
#   Best params: {'fast_period': 5, 'slow_period': 40}
# Best: {'fast_period': 5, 'slow_period': 40} -> Sharpe 1.04

# %%
# Optuna (smart Bayesian search — better for large parameter spaces)
best_opt, params_opt, results_opt = optimize(
    SMACrossover, df, config,
    maximize='sharpe_ratio',
    method='optuna',
    n_trials=30,
    constraint=lambda p: p['fast_period'] < p['slow_period'],
    fast_period=[5, 10, 15, 20, 25],
    slow_period=[20, 30, 40, 50, 60, 70],
)
print(f'\nOptuna best: {params_opt} -> Sharpe {best_opt.sharpe_ratio:.2f}, Return {best_opt.total_return_pct:+.1f}%')
# Out:
# Optimizing SMACrossover [optuna] for 30 trials
#   Maximizing: sharpe_ratio
#   Parameters: fast_period=[5, 10, 15, 20, 25], slow_period=[20, 30, 40, 50, 60, 70]
#   Progress: 1/30 (3%) | Elapsed: 0s | ETA: 1s
#   Progress: 2/30 (7%) | Elapsed: 0s | ETA: 1s
#   Progress: 3/30 (10%) | Elapsed: 0s | ETA: 1s
#   Progress: 4/30 (13%) | Elapsed: 0s | ETA: 1s
#   Progress: 5/30 (17%) | Elapsed: 0s | ETA: 1s
#   Progress: 6/30 (20%) | Elapsed: 0s | ETA: 1s
#   Progress: 7/30 (23%) | Elapsed: 0s | ETA: 1s
#   Progress: 8/30 (27%) | Elapsed: 0s | ETA: 1s
#   Progress: 9/30 (30%) | Elapsed: 0s | ETA: 1s
#   Progress: 10/30 (33%) | Elapsed: 0s | ETA: 1s
#   Progress: 11/30 (37%) | Elapsed: 0s | ETA: 1s
#   Progress: 12/30 (40%) | Elapsed: 0s | ETA: 1s
#   Progress: 13/30 (43%) | Elapsed: 0s | ETA: 0s
#   Progress: 14/30 (47%) | Elapsed: 0s | ETA: 0s
#   Progress: 15/30 (50%) | Elapsed: 0s | ETA: 0s
#   Progress: 16/30 (53%) | Elapsed: 0s | ETA: 0s
#   Progress: 17/30 (57%) | Elapsed: 0s | ETA: 0s
#   Progress: 18/30 (60%) | Elapsed: 1s | ETA: 0s
#   Progress: 19/30 (63%) | Elapsed: 1s | ETA: 0s
#   Progress: 20/30 (67%) | Elapsed: 1s | ETA: 0s
#   Progress: 21/30 (70%) | Elapsed: 1s | ETA: 0s
#   Progress: 22/30 (73%) | Elapsed: 1s | ETA: 0s
#   Progress: 23/30 (77%) | Elapsed: 1s | ETA: 0s
#   Progress: 24/30 (80%) | Elapsed: 1s | ETA: 0s
#   Progress: 25/30 (83%) | Elapsed: 1s | ETA: 0s
#   Progress: 26/30 (87%) | Elapsed: 1s | ETA: 0s
#   Progress: 27/30 (90%) | Elapsed: 1s | ETA: 0s
#   Progress: 28/30 (93%) | Elapsed: 1s | ETA: 0s
# Optimization complete in 0.8s
#   Best sharpe_ratio: 1.0381
#   Best params: {'fast_period': 5, 'slow_period': 40}
#
# Optuna best: {'fast_period': 5, 'slow_period': 40} -> Sharpe 1.04, Return +53.1%

# %%
# Parameter sensitivity heatmap
plot_heatmap(results, 'fast_period', 'slow_period', 'sharpe_ratio',
             output_path='heatmap.png')

from IPython.display import Image, display
display(Image('heatmap.png'))
# Out:
# Heatmap saved to: heatmap.png

# %% [markdown]
# ---
# ## 5. Validate on Synthetic Data

# %%
# Test against oscillating, trending, and random walk data
run_validation_suite(strat, config=config)
# Out:
# Validation Suite: SMA Crossover (10/30)
# =================================================================
#   Oscillating (mean-reverting):
#     Return: -85.03%  |  Sharpe: -10.91  |  Trades: 19  |  Win rate: 0%  |  Max DD: -85.03%
#
#   Trending (strong uptrend):
#     Return: +71.83%  |  Sharpe: 17.15  |  Trades: 0  |  Win rate: 0%  |  Max DD: -0.15%
#   Random Walk (no edge):
#     Return: -16.76%  |  Sharpe: -1.25  |  Trades: 7  |  Win rate: 0%  |  Max DD: -18.46%
# {'Oscillating (mean-reverting)': BacktestResult(strategy_name='SMA Crossover (10/30)', trades=[Trade(entry_date=Timestamp('2020-02-14 00:00:00'), entry_price=np.float64(104.87207134707643), exit_date=Timestamp('2020-03-03 00:00:00'), exit_price=np.float64(95.07324971980475), quantity=953, direction='LONG', gross_pnl=np.float64(-9338.277010789909), fees=np.float64(40.10920618863537), net_pnl=np.float64(-9378.386216978544), return_pct=np.float64(-9.343595011909567), holding_bars=12, entry_reason='enter_long', exit_reason='exit'), Trade(entry_date=Timestamp('2020-03-19 00:00:00'), entry_price=np.float64(105.0221270475956), exit_date=Timestamp('2020-04-07 00:00:00'), exit_price=np.float64(94.64337134846231), quantity=863, direction='LONG', gross_pnl=np.float64(-8956.866168352033), fees=np.float64(36.46190812698919), net_pnl=np.float64(-8993.328076479022), return_pct=np.float64(-9.882446671861523), holding_bars=13, entry_reason='enter_long', exit_reason='exit'), Trade(entry_date=Timestamp('2020-04-23 00:00:00'), entry_price=np.float64(104.70619173619333), exit_date=Timestamp('2020-05-12 00:00:00'), exit_price=np.float64(95.34664626733088), quantity=780, direction='LONG', gross_pnl=np.float64(-7300.445465712711), fees=np.float64(33.207951959049225), net_pnl=np.float64(-7333.65341767176), return_pct=np.float64(-8.938865327509738), holding_bars=13, entry_reason='enter_long', exit_reason='exit'), Trade(entry_date=Timestamp('2020-05-29 00:00:00'), entry_price=np.float64(105.08241050808675), exit_date=Timestamp('2020-06-16 00:00:00'), exit_price=np.float64(95.31413901711745), quantity=708, direction='LONG', gross_pnl=np.float64(-6915.9362156062625), fees=np.float64(30.37587591035533), net_pnl=np.float64(-6946.312091516618), return_pct=np.float64(-9.295819770157987), holding_bars=12, entry_reason='enter_long', exit_reason='exit'), Trade(entry_date=Timestamp('2020-07-02 00:00:00'), entry_price=np.float64(104.61345623050978), exit_date=Timestamp('2020-07-21 00:00:00'), exit_price=np.float64(94.7769278221523), quantity=645, direction='LONG', gross_pnl=np.float64(-6344.560823390575), fees=np.float64(27.721106789204747), net_pnl=np.float64(-6372.28193017978), return_pct=np.float64(-9.402737241262017), holding_bars=13, entry_reason='enter_long', exit_reason='exit'), Trade(entry_date=Timestamp('2020-08-06 00:00:00'), entry_price=np.float64(104.79227566454459), exit_date=Timestamp('2020-08-25 00:00:00'), exit_price=np.float64(95.00091639030059), quantity=583, direction='LONG', gross_pnl=np.float64(-5708.362456884253), fees=np.float64(25.295658790923028), net_pnl=np.float64(-5733.658115675176), return_pct=np.float64(-9.343588744639518), holding_bars=13, entry_reason='enter_long', exit_reason='exit'), Trade(entry_date=Timestamp('2020-09-10 00:00:00'), entry_price=np.float64(104.76424336026504), exit_date=Timestamp('2020-09-29 00:00:00'), exit_price=np.float64(94.95961139050905), quantity=529, direction='LONG', gross_pnl=np.float64(-5186.650312000917), fees=np.float64(23.130577211842507), net_pnl=np.float64(-5209.78088921276), return_pct=np.float64(-9.358757964814057), holding_bars=13, entry_reason='enter_long', exit_reason='exit'), Trade(entry_date=Timestamp('2020-10-15 00:00:00'), entry_price=np.float64(105.35560615041797), exit_date=Timestamp('2020-11-03 00:00:00'), exit_price=np.float64(94.73836899189423), quantity=476, direction='LONG', gross_pnl=np.float64(-5053.804887457298), fees=np.float64(21.04874504330243), net_pnl=np.float64(-5074.8536325006), return_pct=np.float64(-10.077524629648405), holding_bars=13, entry_reason='enter_long', exit_reason='exit'), Trade(entry_date=Timestamp('2020-11-19 00:00:00'), entry_price=np.float64(104.98161227857469), exit_date=Timestamp('2020-12-08 00:00:00'), exit_price=np.float64(95.01623018054465), quantity=430, direction='LONG', gross_pnl=np.float64(-4285.114302152914), fees=np.float64(19.199643734897926), net_pnl=np.float64(-4304.313945887812), return_pct=np.float64(-9.492502431365146), holding_bars=13, en ...
#  2020-01-02    100000.000000
#  2020-01-03    100000.000000
#  2020-01-06    100000.000000
#  2020-01-07    100000.000000
#                    ...
#  2021-11-24     14974.553645
#  2021-11-25     14974.553645
#  2021-11-26     14974.553645
#  2021-11-29     14974.553645
#  2021-11-30     14974.553645
#  Freq: B, Name: Equity, Length: 500, dtype: float64, signals=2020-01-01    Signal.HOLD
#  2020-01-02    Signal.HOLD
#  2020-01-03    Signal.HOLD
#  2020-01-06    Signal.HOLD
#  2020-01-07    Signal.HOLD
#                   ...
#  2021-11-24    Signal.HOLD
#  2021-11-25    Signal.HOLD
#  2021-11-26    Signal.HOLD
#  2021-11-29    Signal.HOLD
#  2021-11-30    Signal.HOLD
#  Freq: B, Length: 500, dtype: object, benchmark_curve=2020-01-01    100000.000000
#  2020-01-02    101335.138159
#  2020-01-03    102330.561769
#  2020-01-06    103160.680667
#  2020-01-07    104090.243194
#                    ...
#  2021-11-24     94926.750281
#  2021-11-25     96729.392126
#  2021-11-26     97263.733711
#  2021-11-29     99065.856074
#  2021-11-30     99676.254966
#  Freq: B, Name: Close, Length: 500, dtype: float64, total_return_pct=np.float64(-85.02544635499936), annual_return_pct=np.float64(-62.923744950758035), benchmark_return_pct=np.float64(-0.3237450335021874), sharpe_ratio=-10.913788307594125, sortino_ratio=-11.751525869181792, calmar_ratio=np.float64(0.7400578020847781), max_drawdown_pct=-85.02544635499936, volatility_annual_pct=8.73448511878162, avg_drawdown_pct=-85.02544635499936, max_drawdown_duration=468, avg_drawdown_duration=468.0, sqn=-8.092769730469191, kelly_criterion=0.0, alpha=np.float64(-84.87278753367373), beta=0.47154027252314196, cagr=-62.923744950758035, num_trades=19, win_rate=0.0, profit_factor=np.float64(0.0), expectancy=np.float64(-4493.011501559122), avg_trade_return_pct=np.float64(-9.513362485682363), avg_win_pct=0.0, avg_loss_pct=np.float64(-9.513362485682363), median_trade_pnl=-3935.4087355280585, max_consecutive_losses=19, avg_holding_bars=12.526315789473685, best_trade_pct=np.float64(-8.938865327509738), worst_trade_pct=np.float64(-10.077524629648405), max_trade_duration=13, avg_trade_duration=12.526315789473685, days_in_market_pct=47.599999999999994, turnover=np.float64(35.765382415838275), period_years=1.9137577002053388, total_commissions=np.float64(38.0), total_slippage=np.float64(341.77217462397743)),
#  'Trending (strong uptrend)': BacktestResult(strategy_name='SMA Crossover (10/30)', trades=[], fills=[Fill(timestamp=Timestamp('2020-02-12 00:00:00'), side='BUY', quantity=955, price=np.float64(104.68156162169389), notional=np.float64(99970.89134871766), commission=np.float64(1.0), slippage_per_share=np.float64(0.020932125899158945), slippage_total=np.float64(19.99018023369679), reason='enter_long')], equity_curve=2020-01-01    100000.000000
#  2020-01-02    100000.000000
#  2020-01-03    100000.000000
#  2020-01-06    100000.000000
#  2020-01-07    100000.000000
#                    ...
#  2021-11-24    171046.414922
#  2021-11-25    171519.082870
#  2021-11-26    171519.161602
#  2021-11-29    171874.357501
#  2021-11-30    171825.166915
#  Freq: B, Name: Equity, Length: 500, dtype: float64, signals=2020-01-01    Signal.HOLD
#  2020-01-02    Signal.HOLD
#  2020-01-03    Signal.HOLD
#  2020-01-06    Signal.HOLD
#  2020-01-07    Signal.HOLD
#                   ...
#  2021-11-24    Signal.HOLD
#  2021-11-25    Signal.HOLD
#  2021-11-26    Signal.HOLD
#  2021-11-29    Signal.HOLD
#  2021-11-30    Signal.HOLD
#  Freq: B, Length: 500, dtype: object, benchmark_curve=2020-01-01    100000.000000
#  2020-01-02    100190.071946
#  2020-01-03    100293.104121
#  2020-01-06    100391.779243
#  2020-01-07    100595.691738
#                    ...
#  2021-11-24    179076.540201
#  2021-11-25    179571.479853
#  2021-11-26    179571.562294
#  2021-11-29    179943.494715
#  2021-11-30    179891.986311
#  Freq: B, Name: Close, Length: 500, dtype: float64, total_return_pct=np.float64(71.8251669149286), annual_return_pct=np.float64(32.690676060067815), benchmark_return_pct=np.float64(79.89198631118136), sharpe_ratio=17.152911370881846, sortino_ratio=49.48507132293787, calmar_ratio=np.float64(224.87655243716773), max_drawdown_pct=-0.14537165260571952, volatility_annual_pct=1.595302199788549, avg_drawdown_pct=-0.04589882471041915, max_drawdown_duration=3, avg_drawdown_duration=2.0, sqn=0.0, kelly_criterion=0.0, alpha=np.float64(-0.1797313895073671), beta=0.901278108469791, cagr=32.690676060067794, num_trades=0, win_rate=0.0, profit_factor=0.0, expectancy=0.0, avg_trade_return_pct=0.0, avg_win_pct=0.0, avg_loss_pct=0.0, median_trade_pnl=0.0, max_consecutive_losses=0, avg_holding_bars=0.0, best_trade_pct=0.0, worst_trade_pct=0.0, max_trade_duration=0, avg_trade_duration=0.0, days_in_market_pct=94.0, turnover=np.float64(0.7468688762878358), period_years=1.9137577002053388, total_commissions=np.float64(1.0), total_slippage=np.float64(19.99018023369679)),
#  'Random Walk (no edge)': BacktestResult(strategy_name='SMA Crossover (10/30)', trades=[Trade(entry_date=Timestamp('2020-03-20 00:00:00'), entry_price=np.float64(86.75892047143017), exit_date=Timestamp('2020-04-13 00:00:00'), exit_price=np.float64(84.48217602991267), quantity=1152, direction='LONG', gross_pnl=np.float64(-2622.809596628169), fees=np.float64(41.453845299679344), net_pnl=np.float64(-2664.2634419278484), return_pct=np.float64(-2.6242194222174997), holding_bars=16, entry_reason='enter_long', exit_reason='exit'), Trade(entry_date=Timestamp('2020-05-13 00:00:00'), entry_price=np.float64(87.33467361195542), exit_date=Timestamp('2020-05-25 00:00:00'), exit_price=np.float64(82.89647827809864), quantity=1114, direction='LONG', gross_pnl=np.float64(-4944.149601916456), fees=np.float64(39.92730439221215), net_pnl=np.float64(-4984.076906308668), return_pct=np.float64(-5.081825064780721), holding_bars=8, entry_reason='enter_long', exit_reason='exit'), Trade(entry_date=Timestamp('2020-09-30 00:00:00'), entry_price=np.float64(73.5479416978347), exit_date=Timestamp('2020-11-04 00:00:00'), exit_price=np.float64(73.18864068887753), quantity=1256, direction='LONG', gross_pnl=np.float64(-451.28206725021164), fees=np.float64(38.86021291866794), net_pnl=np.float64(-490.14228016887955), return_pct=np.float64(-0.4885262601002971), holding_bars=25, entry_reason='enter_long', exit_reason='exit'), Trade(entry_date=Timestamp('2021-01-26 00:00:00'), entry_price=np.float64(64.65982794949505), exit_date=Timestamp('2021-02-02 00:00:00'), exit_price=np.float64(63.665949526065695), quantity=1422, direction='LONG', gross_pnl=np.float64(-1413.2951181165467), fees=np.float64(38.49579604207659), net_pnl=np.float64(-1451.7909141586233), return_pct=np.float64(-1.5370879492683787), holding_bars=5, entry_reason='enter_long', exit_reason='exit'), Trade(entry_date=Timestamp('2021-02-16 00:00:00'), entry_price=np.float64(66.07606077060706), exit_date=Timestamp('2021-03-25 00:00:00'), exit_price=np.float64(65.75118641203322), quantity=1370, direction='LONG', gross_pnl=np.float64(-445.0778712461563), fees=np.float64(38.12064936975456), net_pnl=np.float64(-483.19852061591087), return_pct=np.float64(-0.49166726161489205), holding_bars=27, entry_reason='enter_long', exit_reason='exit'), Trade(entry_date=Timestamp('2021-04-26 00:00:00'), entry_price=np.float64(69.11554046616527), exit_date=Timestamp('2021-06-04 00:00:00'), exit_price=np.float64(66.6204389285945), quantity=1303, direction='LONG', gross_pnl=np.float64(-3251.1173034547205), fees=np.float64(37.37266760048896), net_pnl=np.float64(-3288.4899710552095), return_pct=np.float64(-3.610044167696591), holding_bars=29, entry_reason='enter_long', exit_reason='exit'), Trade(entry_date=Timestamp('2021-08-11 00:00:00'), entry_price=np.float64(66.57881582803427), exit_date=Timestamp('2021-08-30 00:00:00'), exit_price=np.float64(63.8064952020087), quantity=1304, direction='LONG', gross_pnl=np.float64(-3615.1060963373407), fees=np.float64(36.00434587256518), net_pnl=np.float64(-3651.110442209906), return_pct=np.float64(-4.163968060330426), holding_bars=13, entry_reason='enter_long', exit_reason='exit')], fills=[Fill(timestamp=Timestamp('2020-03-20 00:00:00'), side='BUY', quantity=1152, price=np.float64(86.75892047143017), notional=np.float64(99946.27638308756), commission=np.float64(1.0), slippage_per_share=np.float64(0.017348314431399756), slippage_total=np.float64(19.98525822497252), reason='enter_long'), Fill(timestamp=Timestamp('2020-04-13 00:00:00'), side='SELL', quantity=1152, price=np.float64(84.48217602991267), notional=np.float64(97323.4667864594), commission=np.float64(1.0), slippage_per_share=np.float64(0.016899815169016338), slippage_total=np.float64(19.46858707470682), reason='exit'), Fill(timestamp=Timestamp('2020-05-13 00:00:00'), side='BUY', quantity=1114, price=np.float64(87.33467361195542), notional=np.float64(97290.82640371834), commission=np.float64(1.0), slippage_per_share=np.float64(0.017463442 ...
#  2020-01-02    100000.000000
#  2020-01-03    100000.000000
#  2020-01-06    100000.000000
#  2020-01-07    100000.000000
#                    ...
#  2021-11-24     83243.162345
#  2021-11-25     83243.162345
#  2021-11-26     83243.162345
#  2021-11-29     83243.162345
#  2021-11-30     83243.162345
#  Freq: B, Name: Equity, Length: 500, dtype: float64, signals=2020-01-01    Signal.HOLD
#  2020-01-02    Signal.HOLD
#  2020-01-03    Signal.HOLD
#  2020-01-06    Signal.HOLD
#  2020-01-07    Signal.HOLD
#                   ...
#  2021-11-24    Signal.HOLD
#  2021-11-25    Signal.HOLD
#  2021-11-26    Signal.HOLD
#  2021-11-29    Signal.HOLD
#  2021-11-30    Signal.HOLD
#  Freq: B, Length: 500, dtype: object, benchmark_curve=2020-01-01    100000.000000
#  2020-01-02    100298.745538
#  2020-01-03    100023.788708
#  2020-01-06     99132.985008
#  2020-01-07     98682.256287
#                    ...
#  2021-11-24     51787.286199
#  2021-11-25     52060.011911
#  2021-11-26     51499.973612
#  2021-11-29     52035.762417
#  2021-11-30     51474.856477
#  Freq: B, Name: Close, Length: 500, dtype: float64, total_return_pct=np.float64(-16.756837654949575), annual_return_pct=np.float64(-9.138570718692996), benchmark_return_pct=np.float64(-48.525143523464656), sharpe_ratio=-1.246646983048577, sortino_ratio=-0.9349525262300269, calmar_ratio=np.float64(0.49495980433913755), max_drawdown_pct=-18.46325830618644, volatility_annual_pct=7.21901508902099, avg_drawdown_pct=-18.46325830618644, max_drawdown_duration=441, avg_drawdown_duration=441.0, sqn=-3.7851410058391446, kelly_criterion=0.0, alpha=np.float64(-5.517888084140154), beta=0.23161084655782113, cagr=-9.138570718692996, num_trades=7, win_rate=0.0, profit_factor=np.float64(0.0), expectancy=np.float64(-2430.438925206435), avg_trade_return_pct=np.float64(-2.571048312286972), avg_win_pct=0.0, avg_loss_pct=np.float64(-2.571048312286972), median_trade_pnl=-2664.2634419278484, max_consecutive_losses=7, avg_holding_bars=17.571428571428573, best_trade_pct=np.float64(-0.4885262601002971), worst_trade_pct=np.float64(-5.081825064780721), max_trade_duration=29, avg_trade_duration=17.571428571428573, days_in_market_pct=24.6, turnover=np.float64(13.990228044355124), period_years=1.9137577002053388, total_commissions=np.float64(14.0), total_slippage=np.float64(256.23482149544475))}

# %% [markdown]
# ---
# ## 6. Trade Distributions

# %%
generate_distribution_plots(result, 'distributions.png')
display(Image('distributions.png'))

# %% [markdown]
# ---
# ## 7. Scorecard
#
# One call generates 4 presentation slides:
# 1. Bar-Based Backtest (equity curve + metrics)
# 2. Monte Carlo Simulation (placeholder — awaiting module)
# 3. Event-Driven Backtest (placeholder — awaiting module)
# 4. Strategy Scorecard (grades from all tests)

# %%
generate_scorecard(
    strategy=strat,
    df=df,
    config=config,
    symbol=symbol,
    output_path='report.png',
)

print('\nPage 1: Bar-Based Backtest')
display(Image('report_bartest.png'))
print('\nPage 2: Monte Carlo (placeholder)')
display(Image('report_montecarlo.png'))
print('\nPage 3: Event-Driven (placeholder)')
display(Image('report_eventdriven.png'))
print('\nPage 4: Strategy Scorecard')
display(Image('report_scorecard.png'))
# Out:
# Page 1 (Bar-Based Backtest):    report_bartest.png
# Page 2 (Monte Carlo):           report_montecarlo.png
# Page 3 (Event-Driven Backtest): report_eventdriven.png
# Page 4 (Strategy Scorecard):    report_scorecard.png
#
# Page 1: Bar-Based Backtest
# Page 2: Monte Carlo (placeholder)
# Page 3: Event-Driven (placeholder)
# Page 4: Strategy Scorecard

# %% [markdown]
# ---
# ## Writing Your Own Strategy
#
# **Signal mode** (simple):
# ```python
# from strategy.base import Strategy, Signal
# from strategy.helpers import crossover
#
# class MyStrategy(Strategy):
#     def __init__(self, period=20):
#         self.period = period
#
#     @property
#     def name(self): return f'My Strategy ({self.period})'
#
#     def generate_signals(self, df):
#         signals = pd.Series(Signal.HOLD, index=df.index)
#         sma = df['Close'].rolling(self.period).mean()
#         for i in range(1, len(df)):
#             if crossover(df['Close'].values[:i+1], sma.values[:i+1]):
#                 signals.iloc[i] = Signal.BUY
#             elif crossover(sma.values[:i+1], df['Close'].values[:i+1]):
#                 signals.iloc[i] = Signal.SELL
#         return signals
#
#     # Optional: stop-loss / take-profit
#     def get_sl_tp(self, entry_price, direction):
#         return entry_price * 0.95, entry_price * 1.10  # 5% SL, 10% TP
# ```
#
# **Target position mode** (advanced — long/short):
# ```python
# class MyStrategy(Strategy):
#     def __init__(self, lookback=20, threshold=1.5):
#         self.lookback = lookback
#         self.threshold = threshold
#
#     @property
#     def name(self): return 'My Strategy'
#
#     def prepare(self, bars):
#         df = bars.copy()
#         df['zscore'] = (df['Close'] - df['Close'].rolling(self.lookback).mean()) / df['Close'].rolling(self.lookback).std()
#         return df
#
#     def target_position(self, row, state):
#         if row['zscore'] < -self.threshold: return 100   # long
#         if row['zscore'] > self.threshold: return -100   # short
#         if abs(row['zscore']) < 0.5: return 0            # flat
#         return state.current_position                    # hold
# ```
#
# **Full pipeline:**
# ```python
# result = Backtester(config).run(MyStrategy(), df)  # backtest
# print(result.summary())
#
# run_validation_suite(MyStrategy())                  # synthetic data test
#
# optimize(MyStrategy, df, method='optuna',           # optimize
#          n_trials=50, period=[10,15,20,30,50])
#
# generate_distribution_plots(result)                 # trade distributions
#
# generate_scorecard(MyStrategy(), df, config,        # 4-page report
#                    symbol='SPY')
# ```
